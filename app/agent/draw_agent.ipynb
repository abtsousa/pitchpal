# %%
# !uv pip install ipykernel ipywidgets grandalf
# Out:
# Resolved 35 packages in 6ms
#    Building pygraphviz==1.14
#    Building pygraphviz==1.14
#    Building pygraphviz==1.14
#   × Failed to build `pygraphviz==1.14`m==1.14
#   ├─▶ The build backend returned an error
#   ╰─▶ Call to `setuptools.build_meta.build_wheel` failed (exit status: 1)
#
#       [stdout]
#       running bdist_wheel
#       running build
#       running build_py
#       copying pygraphviz/__init__.py ->
#       build/lib.linux-x86_64-cpython-313/pygraphviz
#       copying pygraphviz/agraph.py ->
#       build/lib.linux-x86_64-cpython-313/pygraphviz
#       copying pygraphviz/graphviz.py ->
#       build/lib.linux-x86_64-cpython-313/pygraphviz
#       copying pygraphviz/scraper.py ->
#       build/lib.linux-x86_64-cpython-313/pygraphviz
#       copying pygraphviz/testing.py ->
#       build/lib.linux-x86_64-cpython-313/pygraphviz
#       copying pygraphviz/tests/__init__.py ->
#       build/lib.linux-x86_64-cpython-313/pygraphviz/tests
# ...

# %%
import sys
import os
# Add the parent directory (app) to Python path
sys.path.insert(0, os.path.abspath('..'))

from agent import get_agent
agent = get_agent()

agent.get_graph().print_ascii()
# Out:
#                                   +-----------+
#                                   | __start__ |**
#                                   +-----------+  *****
#                                 ***                   *****
#                               **                           ****
#                             **                                 *****
#                 +------------------+                                ***
#                 | sports_guardrail |                                  *
#                 +------------------+                                  *
#                   ...           ...                                   *
#                 ..                 ...                                *
#               ..                      ..                              *
# +--------------------+                  ..                  +-------------------+
# | hardcoded_response |                   .                  | sports_classifier |
# ...

# %%
# !uv pip install pygraphviz

from IPython.display import Image, display

display(Image(agent.get_graph().draw_png()))
# Out:
# Using Python 3.13.3 environment at: /home/afonso/dev/git/private/tonibot/app/.venv
# Audited 1 package in 1ms

# %% [markdown]
# Hardcoded_response goes to END and not triage - graph bug?
