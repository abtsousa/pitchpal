# %%
# !uv pip install ipykernel ipywidgets grandalf
# Out:
# Using Python 3.13.3 environment at: /home/afonso/dev/git/private/pitchpal/app/.venv
# Audited 3 packages in 9ms

# %%
import sys
import os
# Add the parent directory (app) to Python path
sys.path.insert(0, os.path.abspath('..'))

from agent import get_agent
agent = get_agent()

agent.get_graph().print_ascii()
# Out:
#                                               +-----------+
#                                               | __start__ |
#                                               +-----------+
#                                             ***           ***
#                                           **                 **
#                                         **                     **
#                            +-------------------+         +------------------+
#                            | sports_classifier |         | sports_guardrail |
#                            +-------------------+         +------------------+
#                                             ***           ***
#                                                **       **
#                                                  **   **
#                                                +--------+
#                                            ....| triage |.....
#                                  ..............+--------+     .........
#                        ..........       ...              ...           ........
#              ..........             ....                    .                  .........
#         .....                     ..                         ..                         .....
# +-------+....     +------------------------+         +--------------------+         +-----------------------------+
# | agent |    .....| future_sports_response |         | hardcoded_response |         | unsupported_sports_response |
# +-------+         +------------------------+**       +--------------------+         +-----------------------------+
#     *                         .........       ******            *              *******
#     *                                  .........    ******       *        *****
#     *                                           ........  ***    *    ****
# +-------+                                               ....+---------+
# | tools |                                                   | __end__ |
# +-------+                                                   +---------+

# %%
# Mermaid API is down today so we use pygraphviz instead
# !uv pip install pygraphviz

from IPython.display import Image, display

display(Image(agent.get_graph().draw_png()))
# Out:
# Using Python 3.13.3 environment at: /home/afonso/dev/git/private/pitchpal/app/.venv
# Audited 1 package in 3ms
